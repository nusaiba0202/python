# %%
name = input("enter your name: ")
marks = int(input("enter your marks: "))

if marks <=100 and marks >=80:
    print(name, "your marks is:", marks,"you have A pass")
elif marks >=60:
    print(name, "your marks is:", marks,"you have B pass")
elif marks >=40:
    print(name, "your marks is: ", marks, "you have C pass")
else:
    print(name, "your marks is:")
