# %%
name = input("enter your name? ")
print(name)
# Out:
# enter your name?  nusaiba
# nusaiba

# %%
name = "nusaiba"
print(name)
# Out:
# nusaiba

# %%
x = 2
y = 3
sum = x + y
print(sum)
# Out:
# 5

# %%
x = 2
y = 3
print("the sum is:", x + y)
# Out:
# the sum is: 5

# %%
age = 23
print(f"i am {age} years old")
# Out:
# i am 23 years old

# %%
#other method
age = 23
print("im",age, "yeard old")
# Out:
# im 23 yeard old

# %%
school = "APIIT"
print(school)
# Out:
# APIIT

# %%
#section B
current_year = 2025
birth_year = 2002
age = current_year - birth_year
print(age)
# Out:
# 23

# %%
celsius = int(input("enter the temperature? "))
fahrenheit = (celsius * 9)/5 +32
print(fahrenheit)
# Out:
# enter the temperature?  27
# 80.6

# %%
r = int(input("enter the radius? "))
area = 3.14 * r **  r
print(area)
# Out:
# enter the radius?  3
# 84.78

# %%
days = int(input("enter the days count?" ))
weeks = days // 7
remaining_days = days % 7
print("days is", weeks,"weeks and remianing_days is", remaining_days)
# Out:
# enter the days count? 34
# days is 4 weeks and remianing_days is 6

# %%
#section C
hour = int(input("enter your work hour? "))
rate = int(input("enter the amonut per hour?  "))
total_pay = hour * rate
print("total payment is:",total_pay)
# Out:
# enter your work hour?  3
# enter the amonut per hour?   100
# total payment is: 300

# %%
current_year = 2025
birth_year = int(input("enter your birth year? "))
age = current_year - birth_year
print(age)
# Out:
# enter your birth year?  2002
# 23
