# %%
#Conditional Statement
#if-else
#if[condition]
    #do something
    #do something
#else
    #do something

#nested if-else
#if[condition]
    #if[condition]
        #do something
    #else
        #do something
#else
    #something

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Enter your age:  25
# Adult

# %%
marks = int(input("ënter your marks: "))

if marks > 50:
    print("pass")
else:
    print("fail")
# Out:
# ënter your marks:  51
# pass

# %%
marks = int(input("enter your marks: "))

if marks >= 75:
    print("Grade A")
elif marks >= 65:
    print("Grade B")
elif marks >=50:
    print("Grade C")
else:
    print("fail")
# Out:
# enter your marks:  54
# Grade C

# %%
#method 1
num = int(input("ënter any number: "))

if num > 0:
    print("positive num")
elif num < 0:
    print("Negative num")
else:
    print("Zero")
# Out:
# ënter any number:  0
# Zero

# %%
#method 2
num = int(input("enter any num: "))
if num > 0:
    print("positive")
else:
    if num < 0:
        print("Negative")
    else:
        print("Zero")
# Out:
# enter any num:  4
# positive

# %%
age = int(input("enter your age: "))
if age >= 18:
    print("you are eligible to vote")
else:
    print("ÿou are not eligible to vote")

# %%
#method 1
num = int(input("enter the num: "))
if num%2==1:
    print("odd num")
else:
    print("even num")
# Out:
# enter the num:  11
# odd num

# %%
#method 2
num = int(input("enter the num: "))
if num%2==0:
    print("even num")
else:
    print("odd num")
# Out:
# enter the num:  50
# even num

# %%
name = input("enter the name: ")
marks = int(input("enter the marks: "))
print("enterd marks are: ", marks)

if 100>= marks >=85:
    print("excellent", name, "you have A pass")
elif marks >=75:
    print("Great", name, "you have B pass")
elif marks >=65:
    print("good", name, "you have C pass")
elif marks >= 50:
    print("fair", name, "you have D pass")
else:
    print("sorry", name, "you have failed. try agian")
# Out:
# enter the name:  nus
# enter the marks:  45
# enterd marks are:  45
# sorry nus you have failed. try agian

# %%
#nested if
x=10
y=20

if x > 5:
    if y>15:
        print("both conditions are true")
    else:
        print("only x>5 is true")
else:
    print("x is not greater than 5")
# Out:
# both conditions are true

# %%
score = int(input("enter the xm score: "))
if score >=90 and score <= 100:
    print("grade A")
elif score >=80:
    print("grade B")
elif score >= 70:
    print("grade C")
elif score >= 60:
    print("grade C")
elif score >= 0:
    print("grade F")
else:
    print("invalid score entered")
# Out:
# enter the xm score:  -1
# invalid score entered
