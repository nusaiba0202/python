# %%
#variable decalaration
name = "nusaiba"
age = 23
height = 2.14

#take a output
print(name)
print(age)
print(height)
# Out:
# nusaiba
# 23
# 2.14

# %%
#verify the variable types
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#comparision operators
a=5
b=2
#1.
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
#logical operators(and, or, not)
#and = both option 
#or = this or that
#not = not both
# ex:-
(4>5) and (11>5)
# Out:
# False

# %%
(9>3) or (7>5)
# Out:
# True

# %%
#and logical operators
# A       B        C(out put)
#false  false     false
#false  Truse     False 
#True   False     False
#Truse  True      True

#or logical operators
#False   False    False
#False   True     True
#True    False    True
#True    True     True

#Not logical operators
# A         B(out put)
#False     True
#True      False

# %%
print (True or True)
# Out:
# True

# %%
math_marks = 67
science_marks = 43

print(math_marks > 50 or science_marks > 50)
# Out:
# True

# %%
# in class practicals
#ques 1
#write a python command to get name as user input 
#write a python command to get age as user input 
#write a python command to get height as user input 
#print the variable names and values on each line

name = "Nusaiba"
age = 23
height = 5.2

print(name,age,height)
print("name:" ,name ,"age:" ,age, "height: ",height )
# Out:
# Nusaiba 23 5.2
# name: Nusaiba age: 23 height:  5.2
